# %% [markdown]
# #  Introduction to Exploratory Data Analysis (EDA)

# %% [markdown]
# 1. We will learn about some simple plotting tools used in Exploratory Data Analysis (EDA).
#
# 2. **What is EDA exactly? Exploratory Data Analysis** is the process of examining and understanding a dataset using fundamental techniques from statistics, basic plotting, linear algebra, and other analytical tools. It’s the very **first and arguably one of the most critical steps** in any data science or machine learning workflow.
#
# 3. The reason it’s called “exploratory” is because, at this stage, we typically know very little about the data. **The goal is to investigate and make sense of the dataset** — like a data detective or a Sherlock Holmes, looking for clues and insights. EDA helps us uncover patterns, spot anomalies, understand relationships between variables, and lay the groundwork for any future modeling.

# %% [markdown]
# ## IRIS Flower Dataset

# %% [markdown]
# ### 🌸 Toy Dataset: Iris Dataset
#
# 🔗 [Iris Dataset on Wikipedia](https://en.wikipedia.org/wiki/Iris_flower_data_set)
#
# * A simple dataset used widely for learning the basics of machine learning
# * Contains **3 species** of Iris flowers:
#
#   * *Iris Setosa*
#   * *Iris Versicolor*
#   * *Iris Virginica*
# * Introduced in **1936** by **Ronald Fisher**. In 1936, this dataset was collected from 3 types of flowers of IRIS family.
# * Features include:
#
#   * **Sepal Length**
#   * **Sepal Width**
#   * **Petal Length**
#   * **Petal Width**
#
# 🖼️ View labeled Iris image:
# <br>
# ![Iris Image](https://terpconnect.umd.edu/~petersd/666/html/iris_with_labels.jpg)
#
# ---

# %% [markdown]
# ### IRIS Dataset
# The dataset contains a set of 150 records under five attributes: sepal length, sepal width, petal length, petal width and species.

# %% [raw]
# # You can download iris dataset from sklearn.datasets
# # Change this cell to code to download 'iris_dataset.csv'
# from sklearn.datasets import load_iris
# import pandas as pd
#
# iris = load_iris(as_frame=True)
# df = pd.concat([iris.data, iris.target.rename('species')], axis=1)
# df['species'] = df['species'].map(dict(enumerate(iris.target_names)))
#
# df.to_csv('iris_dataset.csv', index=False)

# %%
import pandas as pd
pd.read_csv('iris_dataset.csv')
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 0       setosa
# ...

# %% [markdown]
# ### 🎯 Objective
#
# > Classify a flower as belonging to one of the 3 classes based on the 4 features.
#
# ---
#
# ### 📚 Introduction
#
# * This is a **real-world** dataset but considered a **toy dataset** due to its simplicity.
# * Used in most ML courses and textbooks to explain core concepts.
# * Equivalent to "Hello World" in programming for data science.
#
# ---
#
# ### 📋 What is a Dataset?
#
# * A **dataset** is a **table** with rows and columns.
# * Each **row** = an **observation** or **data point**.
# * Each **column** = a **variable** or **feature**.
#
# ---
#
# ### 🌺 Iris Dataset Specifics
#
# * Contains measurements from 3 types of iris flowers.
# * Task: Given a new flower, classify it as *Setosa*, *Versicolor*, or *Virginica*.
# * Biologists/botanists use 4 measurements to distinguish species:
#
#   * Sepal Length & Width
#   * Petal Length & Width
#
# ---
#
# ### 🧠 Why These Features?
#
# * Selected based on **domain knowledge** by botanists.
# * Botanists know these 4 features help distinguish the species.
# * Example: A botanist can predict species from these 4 values.
#
# ---
#
# ### 🌱 What is a Petal and Sepal?
#
# * **Sepal**: Outer part of the flower (protects budding petals)
# * **Petal**: Inner, often colorful part of the flower
#
# Each has:
#
# * **Length**: Straight-line length in cm
# * **Width**: Width in cm
#
# Refer image above to visualize them.
#
# ---
#
# ### 🧮 Data Representation
#
# * The dataset has 4 features → each observation is a **4-dimensional vector**.
# * **Feature terms**:
#
#   * Feature = Variable = Input Variable = Independent Variable
# * **Output terms**:
#
#   * Label = Class = Output Variable = Dependent Variable
#
# ---
#
# ### 🔢 Vectors, Scalars & Dimensions
#
# * A **vector** = an n-dimensional array (e.g., \[5.1, 3.5, 1.4, 0.2])
# * **Scalar** = 1D vector (e.g., 5.1)
# * **Observation** = vector = data point = row in the dataset
#
# ---
#
# ### 🧪 Summary of Terminology
#
# | Term            | Meaning                                         |
# | --------------- | ----------------------------------------------- |
# | Dataset         | Full table of data                              |
# | Feature         | Column in dataset(e.g., petal width) <br> Also called as Variable/ Input Variable/ Independent Variable|
# | Observation     | Row in dataset = one flower's measurements  <br> Also called as Data Point/ 4D Vector    |
# | Vector          | n-dimensional array (consider Vector as 4D array for the 4 values in each row) <br> 1D is Scalar <br> we will more on Vector in Linear Algebra|
# | Label           | The target output/ Output Variable/ Class (species name) <br> Also called as Class/ Class Label/ Response Label/ Output Variable/ Dependent Variable|
#
# ---
#
# ### 🤔 Why Not Use Color or Shape?
#
# * Botanists did not find **color** or **shape** to be reliable predictors.
# * Domain knowledge tells us which features **matter**.
# * Machine learning is not just number crunching—it requires understanding the **context**.
#
# ---
#
# ### 👩‍🔬 Role of Domain Knowledge
#
# * Always begin by understanding the **problem and data**.
# * Consult experts if unsure (e.g., botanists here).
# * Algorithms mimic what experts do, using measurable data.
#
# ---
#
# ### 🕵️ Sherlock Holmes Mode
#
# * Be curious and question:
#
#   * How many data points are in the dataset?
#   * What are the common terms used?
#   * What are we solving and why?
#
# ---
#
# 🧠 *"Machine learning is about understanding data, not just crunching numbers. In ML, focus on insight and interpretation, not just the codebase size."*
#
# ---

# %% [markdown]
# * In machine learning and exploratory data analysis (EDA), the amount of code written is typically very minimal compared to traditional software engineering.
# * What’s more important is the quality and depth of analysis, not just the quantity of code.
# * Basic programming skills are necessary, but you won’t be writing hundreds or thousands of lines.
# * Most ML tasks are solved with just a few dozen lines of code.
# * The example shown involves simply reading a CSV file using pandas.
# * The key question after loading the data:
#    * 👉 “How many data points and features are there?”

# %% [markdown]
# ### Lets start Exploratory Data Analysis

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Load iris_dataset.csv into a pandas dataframe
iris = pd.read_csv("iris_dataset.csv")

# %%
# Q) How many data points and features?
iris.shape
# Out:
# (150, 5)

# %%
# Q) What are the column names in our dataset?
iris.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'species'],
#       dtype='object')

# %%
# Q) How many data points for each class are present ?
# (or) How many flowers for each species are present ?

iris["species"].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %% [markdown]
# ### Balanced vs Imbalanced Dataset
# * The above dataset are **balanced dataset** because you have equal no of data points for each classes
# * **Imbalanced Dataset**
#
# Imagine you are a Data Scientist working at a hospital, which has 10k patients. Each patients has many fields f1, f2, f3.. f10. Each field could be result of medical test, medical examination, doctor prescribtion, etc. If I have 10 features and I have 10k patients, each patient represented by a row here. Now, for each patient I have a response or a class label which says whether this patient has diabetes or not. So, let us assume there are 500 patients out of my 10,000 who have diabetes and 9,500 of them who do not have diabetes. So, they are non-diabetic, okay.
#
# Now, your task is given these 10 features which correspond to some medical tests, you have to predict whether the patient has diabetes or not.
#
# Now, here if you notice you have a data set with 500 data points of one label of one class label which is diabetes and 9,500 of the other label which is non-diabetic. Now, this is called an imbalanced data set, this is called an imbalanced data set because you have two class labels and the number of data points per class label are very very different.
#
# Now, you might ask what if I had 4,000 patients who are diabetic and 6,000 patients who are non-diabetic. If this was the case would you call it an imbalanced data set? I would say this is almost balanced because it is not as severely imbalanced as 500,9500 right. So, this is okay.
#
# The reason we are specifically calling out imbalanced data sets is because when you have an imbalanced data set we have to do slightly different data analysis as compared to a balanced data set, slightly different not significantly different, but slightly different and it is important to understand whether your data set is balanced or not.
#
# In our case thankfully for the iris data set it is a very balanced data set.
# <br>
# <img src="attachment:b3b800df-6bc0-4c45-89a6-f2fb4dbed034.png" width="400"/>

# %% [markdown]
# ## 📊 Matplotlib - 2D Scatter Plot
#
# Let’s explore a simple yet powerful visualization tool: the **2D Scatter Plot**.

# %% [markdown]
# #### 🔍 Objective:
# Visualize how two features — **sepal length** and **sepal width** — vary across the Iris dataset.

# %%
iris.plot(kind='scatter', x='sepal length (cm)', y='sepal width (cm)');
plt.show()

# %% [markdown]
# #### 📌 Key Points:
# - **X-axis:** `sepal_length`
# - **Y-axis:** `sepal_width`
# - The dataset has **150 data points** (flowers), each represented by a dot.
# - Each point is plotted based on its `sepal_length` and `sepal_width`.
#
# ---
#
# #### 📉 Plot Interpretation Tips:
# - Always **check axis labels** and **read the scale**.
# - For example, in this plot:
#   - `x` starts around **4**
#   - `y` starts around **2**
# - These axes **do not start from 0**, so it’s important to interpret the scale carefully.
#
# ---
#
# #### 🔬 Understanding the Plot:
# - This plot shows that:
#   - `sepal_length` varies from **~4 to ~8**
#   - `sepal_width` varies from **~2 to ~4.5**
# - The scatter plot reveals how these two variables relate, but **not the species** classification.
#
# ---
#
# #### 🎨 What’s Missing?
# - We **cannot tell** which point belongs to **Setosa**, **Versicolor**, or **Virginica**.
# - **✅ Solution:** Color-code the species in the scatter plot!
#
# ---
#
# #### 🧠 Bonus Concept: Dimensionality
# - We’re plotting only **2 dimensions (features)** here.
# - In physics, you have headr of 4 dimension is time. In ML, datasets often have **many dimensions** — i.e. nothing but the **features**!
# - Each **dimension = one feature** (e.g., sepal length, petal width, etc.). 100D means here 100 features.
# - Visualizing **high-dimensional data** is complex — more on this later.
#
# ---
#
# #### ✅ Conclusion:
# A **basic scatter plot** gives an initial understanding of relationships between two variables.
# To make it **more informative**, **add colors for class labels**!

# %% [markdown]
# ## 📊 Matplotlib - 2D Scatter Plot (Color)

# %% [markdown]
# 🔹 What it does:
# * Manually plots each class (species) in a different color using a loop or separate calls.
#
# 📌 Use Case:
# * Use when you want more control but still work directly with Matplotlib — great for teaching or custom plots.
#
#
# **Compare above Matplotlib – Basic 2D Scatter Plot (Without Color)**
# <br>
# 🔹 What it does:
# * Plots all points in one color.
# * No grouping by species.
#
# 📌 Use Case:
# * Good for quick visual checks when you’re not yet interested in class labels.

# %%
# Define color map for species
colors = {
    "setosa": "red",
    "versicolor": "green",
    "virginica": "blue"
}

# Plot each species separately
for species, color in colors.items():
    subset = df[df["species"] == species]
    plt.scatter(
        subset["sepal length (cm)"],
        subset["sepal width (cm)"],
        label=species,
        color=color,
        alpha=0.7
    )

# Plot formatting
plt.title("Sepal Length vs Sepal Width (Color-coded by Species)")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Sepal Width (cm)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 10
#       8 # Plot each species separately
#       9 for species, color in colors.items():
# ---> 10     subset = df[df["species"] == species]
#      11     plt.scatter(
#      12         subset["sepal length (cm)"],
#      13         subset["sepal width (cm)"],
#    (...)
#      16         alpha=0.7
#      17     )
#      19 # Plot formatting
#
# NameError: name 'df' is not defined

# %%
print(df.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 print(df.columns)
#
# NameError: name 'df' is not defined

# %%
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 print(df.head())
#
# NameError: name 'df' is not defined

# %%
print(df[["sepal length (cm)", "sepal width (cm)"]].dtypes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 print(df[["sepal length (cm)", "sepal width (cm)"]].dtypes)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## 📊 Seaborn – 2D Scatter Plot

# %% [markdown]
# 💡 **Why Use Seaborn?**
# * Cleaner syntax
# * Automatic legends and color handling
# * Prettier default styling
# * Works seamlessly with Pandas DataFrames

# %% [markdown]
# **Seaborn – 2D Scatter Plot with scatterplot()**
# * 🔹 What it does:
#     * Uses hue parameter to automatically color-code based on a category like species.
#     * Single plot, but cleaner and more beautiful than matplotlib.
#
# * 📌 Use Case:
#     * Ideal for quick EDA, teaching, and prettier plots with automatic legend & color handling.
#       You want clean, beautiful plots with minimal code
#     * You’re working with a Pandas DataFrame
#     * You need categorical coloring via hue
#     * You want interactive legends and smart layouts
#
# **Seaborn – 2D Scatter Plot with FacetGrid**
# * 🔹 What it does:
#     * Allows creation of faceted plots (grids of subplots) by specifying col, row, or hue.
#     * Automatically handles subplot creation based on categorical variables.
#     * 	✅ hue="species" → creates one plot, with different colors for each species.
#     * 	✅ col="species" or row="species" → creates multiple subplots, one for each species.
#
# * 📌 Use Case:
#     * You want one subplot per category for clearer separation.
#     * You’re comparing distributions across classes.
#     * Ideal when overlapping points in a single plot make analysis harder.
#     * Best used to analyze per-class patterns independently.
#     * Useful in exploratory data analysis for categorical comparisons.

# %% [markdown]
# ### Seaborn – 2D Scatter Plot with scatterplot()

# %%
sns.scatterplot(data=iris, x="sepal length (cm)", y="sepal width (cm)", hue="species")
plt.title("Seaborn Scatter Plot with hue")
plt.show()

# %% [markdown]
# ### Seaborn – 2D Scatter Plot with FacetGrid

# %% [markdown]
# **col="species"**

# %%
sns.set_style("whitegrid")
facetGridObj = sns.FacetGrid(iris, col="species", height=4);
facetGridObj.map(plt.scatter, "sepal length (cm)", "sepal width (cm)");
facetGridObj.add_legend();
plt.show();

# %% [markdown]
# **hue="species"**

# %%
sns.set_style("whitegrid")
facetGridObj = sns.FacetGrid(iris, hue="species", height=4);
facetGridObj.map(plt.scatter, "sepal length (cm)", "sepal width (cm)");
facetGridObj.add_legend();
plt.show();

# %% [markdown]
# **row="species"**

# %%
sns.set_style("whitegrid")
facetGridObj = sns.FacetGrid(iris, row="species", height=4);
facetGridObj.map(plt.scatter, "sepal length (cm)", "sepal width (cm)");
facetGridObj.add_legend();
plt.show();

# %% [markdown]
# #### 📏 height=4 in FacetGrid

# %% [markdown]
# * height=4 sets the height (in inches) of each subplot (facet) in the grid.
# * The width is automatically determined by the aspect ratio (which defaults to 1), so the default subplot size is 4 inches × 4 inches.
#
# * If you set:
#     * sns.FacetGrid(df, col="species", height=5)
#     * Each subplot will be 5 inches tall and 5 inches wide (square), unless you change the aspect.
#
# * You can also control the width/height ratio using aspect:
#     * sns.FacetGrid(df, col="species", height=4, aspect=1.5)
#     * This will make each subplot:
#         * Height: 4 inches
#         * Width: 4 × 1.5 = 6 inches

# %% [markdown]
# ## Analysis (EDA) on last SNS plot

# %%
sns.set_style("whitegrid")
facetGridObj = sns.FacetGrid(iris, hue="species", height=4);
facetGridObj.map(plt.scatter, "sepal length (cm)", "sepal width (cm)");
facetGridObj.add_legend();
plt.show();

# %% [markdown]
# ### 📌 What We See from the Plot
#
# - **Colors:**
#   - Setosa: Blue
#   - Versicolor: Orange
#   - Virginica: Green
# - **Axes:**
#   - X-axis → `sepal length (cm)`
#   - Y-axis → `sepal width (cm)`
#
# ---
#
# ### 🔍 Key Observations
#
# - This is a **2D scatter plot** using two features: `sepal length` and `sepal width`.
# - All **Setosa (blue)** points are clearly **separated** from others.
# - **Versicolor (orange)** and **Virginica (green)** points **overlap heavily**.
#
# ---
#
# ### 🧠 Can We Separate Using a Line?
#
# - Imagine drawing a **line** in this 2D space:
# - A line in 2D is: `y = mx + c`
# - ✅ You **can** draw a line that separates **Setosa** from the rest.
# - ❌ You **cannot** cleanly separate **Versicolor** and **Virginica**.
# - Any line will have **mixed points** on both sides.
#
# ---
#
# ### ✨ Concept: Linear Separability
#
# - A dataset is **linearly separable** if a **line (or hyperplane)** can divide the classes.
# - In this case:
#   - ✅ **Setosa** is **linearly separable** from the others.
#   - ❌ **Versicolor** and **Virginica** are **not linearly separable** using just sepal features.
#
# ---
#
# ### 🤔 What Next?
#
# - Explore **other features**:
#   - Maybe `petal length` or `petal width` gives better separation.
# - So far we used only:
#   - `sepal length`
#   - `sepal width`
#
# ---
#
# ### 📘 Concept Recap: What is a 2D Scatter Plot?
#
# - A **2D scatter plot**:
#   - Plots each **observation (flower)** using **two numerical features**.
#   - **X-axis** and **Y-axis** represent those features.
#   - **Color** encodes the **class label** using the `hue` parameter.
#
#
# - **Now the immediate question is why cannot I draw 3D scatterplots? Of course you can, let us go and see how to draw a 3D scatterplot.**
# ---

# %% [markdown]
# ## 📊 3D Scatter Plot with Plotly

# %% [markdown]
# #### ✅ What We’re Doing
# - https://plotly.com/python/3d-scatter-plots/
# - Plotting **3D scatter plots** using **Plotly**, a Python library.
# - Plotly allows **interactive** plots you can rotate and explore with your mouse.
# - Axes Represent
#     - **X-axis** → Sepal length
#     - **Y-axis** → Sepal width
#     - **Z-axis** → Petal length
# - Color Coding in the Plot
#     - **Red** → Setosa
#     - **Blue** → Versicolor
#     - **Green** → Virginica
#
# ---
#
# #### 👀 Interpreting the Plot
# - You can **rotate** and interact with the 3D plot to get better spatial intuition.
# - **Setosa** flowers are **well-separated** from Versicolor and Virginica in 3D space.
# - This was harder to see in **2D plots**.
#
# ---
#
# #### 🧠 Why 3D Helps
# - In 2D: We drew a **line** to separate Setosa from others.
# - In 3D: You can draw a **plane** (linear surface) to separate classes.
#   - For example:
#     - A plane could separate Setosa from others clearly.
#     - Petal length seems **helpful** in distinguishing classes.
#     - <img src="attachment:71ca089c-f2d3-4d2b-92dc-382531e68189.png" width="600"/>
# ---
#
# #### 🤔 Insights from 3D
# - Adding **petal length** provides **better separation** between classes.
# - This tells us:
#   - Features like **petal length** might be **more informative** than sepal width.
#
# ---
#
# #### ⚠️ Limitations of 3D Plots
# - Difficult to:
#   - Print or export to paper/PDF.
#   - Embed in notebooks cleanly.
# - Require **mouse interaction** to explore properly.
# - Not always practical for static analysis or documentation.
#
# ---

# %% [markdown]
# ### ❓ What About 4D, 5D, and ND Plots?
#
# #### ❓ Can We Visualize More than 3 Dimensions?
# - **Humans evolved** in a **3D world** — we can visualize:
#   - Length
#   - Breadth
#   - Depth
# - We cannot **directly** see or visualize:
#   - 4D
#   - 5D
#   - ND (n ≥ 4)
#
# ---
#
# #### 🐾 Fun Fact
# - Some animals like **insects** that don’t fly might **perceive only 2D** (they only walk on flat ground).
# - Humans can visualize up to **3D**, but no more — for higher dimensions we need **math + tricks**.
#
# ---
#
# ### 🛠️ Visualizing Higher Dimensions
#
# #### 🧠 How Do We “See” 4D or More?
# - Use **mathematical tools** and **hacks** to visualize data in high dimensions.
# - For example:
#   - Our dataset has 4 features:
#     - Sepal length
#     - Sepal width
#     - Petal length
#     - Petal width
#   - That means it’s **4D**.
#
# ---
#
# #### 🧩 Solution: Pair Plots
# - **Pair plots** help visualize high-dimensional data **pairwise**.
# - You’ll see **2D plots** of every possible pair of features.
# - This is the next topic you’ll explore.

# %% [markdown]
# ## 🌺 Visualizing 4D Data with Pair Plots

# %%
plt.close();
sns.set_style("whitegrid");
sns.pairplot(iris, hue="species", height=3);
plt.show();

# %% [markdown]
# ### 🛠️ Pair Plot
#
# * A **pair plot** visualizes all **2D projections** of the dataset.
# * Or we can say **Pairwise Scatter Plot** is called **Pair-Plot**
# * Since we have 4 features:
#     * Sepal length, Sepal width, Petal length and Petal width
#     * We can create **4C2 = 6** unique 2D plots.
#     * <img src="attachment:cf85941b-f583-4748-90e4-5e1ff8afc4f3.png" width="400"/>
# * Each plot shows a **pairwise** relationship between two features.
# * Advantages: -
#     * Can be used when number of features are high
#     * Can't visulaize higher Dimensional Patters in 3D and 4D. Only possible to view 2D patterns.

# %% [markdown]
# ### 📈 How It Works
#
# * Use `sns.pairplot(iris, hue="species")` to generate the plots.
# * The result is a **matrix of plots**:
#   * Rows → y-axis labels
#   * <img src="attachment:fbf80f0e-200c-4961-9f3f-b55b22c98e79.png" width="400"/>
#   * Columns → x-axis labels
#   * <img src="attachment:4f044fef-d58e-4a3c-abf8-79fa38a9f8b4.png" width="400"/>
#   * Diagonal → Histograms (for now, ignore these)
#
# * Each cell in the matrix is a **scatterplot** for a feature pair.
# * You’ll see **color-coded classes**:
#   * Blue: Setosa
#   * Orange: Versicolor
#   * Green: Virginica

# %% [markdown]
# ### 🔄 Symmetry of Pair Plots
#
# * The plot matrix has **redundancy**:
#   * Upper triangle and lower triangle are **mirror images**.
# * Focus on **upper triangle (above diagonal)** to reduce redundancy.
# * <img src="attachment:e58f8297-3398-413a-9c0d-6bf89a052103.png" width="400"/>

# %% [markdown]
# ### 🧠 Observations from Pair Plot
#
# * **Setosa** is well-separated in almost all pairwise views. Till now we have have seen the example of Sepal length vs Sepal Width
# * Especially clear in:
#
#   * Petal length vs Petal width
#   * Sepal length vs Petal length
# * **Versicolor and Virginica** overlap more and are **not linearly separable**.

# %% [markdown]
# ### ✅ Example: Manual Classification Rule
#
# #### 🟦 Setosa:
#
# ```python
# if petal_length <= 2 and petal_width <= 1:
#     return "Setosa"
# ```
#
# #### 🟧 Versicolor:
#
# ```python
# elif 1 < petal_width <= 2 and 2.5 < petal_length < 5:
#     return "Versicolor"
# ```
#
# #### 🟩 Virginica:
#
# ```python
# else:
#     return "Virginica"
# ```

# %% [markdown]
# ### 💡 Key Takeaways
#
# * Features like **petal length** and **petal width** are more discriminative.
# * You don’t always need fancy ML algorithms — **simple visual intuition** helps too.
#
# ---
#
# ### 🎯 Final Summary
#
# * **Pair plots** are powerful tools for visualizing high-dimensional data. **Pair plot** breaks down 4D data into digestible 2D slices.
# * Helps identify which feature pairs are best for classification.
# * You just created your **simple classification model** using only visual insights!
# * An incredibly useful tool for **Exploratory Data Analysis (EDA)**.

# %% [markdown]
# ## 🚫 Limitations of Pair Plot
#
# - In this example, we had **4 features**: SL, SW, PL, PW
#
# ---
#
# ### ❓ What if we had more features?
#
# - 📈 **d = 10 features** → Number of pairwise plots = **10C2 = 45**
# - 📈 **d = 100 features** → Number of pairwise plots = **100C2 = 4,950**
# - 📈 **d = 1000 features** → Number of pairwise plots = **1000C2 = 499,500**
#
# ---
#
# ### ⚠️ Pair Plot Becomes Unusable When:
# - Number of features (**d**) grows beyond **4–6**
# - It becomes visually cluttered and hard to interpret
# - Not feasible to scroll through thousands of plots to find patterns
#
# ---
#
# ## 🧪 What’s the Solution?
#
# To deal with high-dimensional data, we use **Dimensionality Reduction Techniques**:
# - 🔄 **Linear Algebra**
# - 📉 **PCA (Principal Component Analysis)** – Projects data onto fewer dimensions while preserving variance
# - 🌌 **t-SNE (t-Distributed Stochastic Neighbor Embedding)** – Captures nonlinear structure and helps visualize in 2D/3D
#
# > ✅ These techniques reduce the data dimensions while preserving important relationships, making visualization feasible even when **d = 1000**
#
# ---

# %% [markdown]
# ## 📈 1D Scatter Plots and Beyond

# %% [markdown]
# ### ❓ Introduction
#
# * We've already explored 2D and 3D scatter plots.
# * Realized that 4D scatter plots are not directly possible. And used **pair plots** as a workaround for 4D data.
# * Now we ask: **What about 1D scatter plots?**

# %% [markdown]
# ### 🔹 How 1D Scatter Plot Works
# * Choose a single feature (e.g. **petal length**).
# * X-axis: Petal Length
# * Y-axis: Set to **0 for all points** (no meaningful vertical component).

# %%
# Extract subsets by species

# New DataFrame with only the subset of data for the species setosa.
iris_setosa = iris.loc[iris["species"] == "setosa"]
# New DataFrame with only the subset of data for the species versicolor.
iris_versicolor = iris.loc[iris.species == "versicolor"]
# New DataFrame with only the subset of data for the species virginica.
iris_virginica = iris[iris.species == "virginica"]

# Scatter plots with y=0
plt.plot(iris_setosa["petal length (cm)"], np.zeros_like(iris_setosa["petal length (cm)"]),'o', label='setosa')
plt.plot(iris_versicolor["petal length (cm)"], np.zeros_like(iris_versicolor["petal length (cm)"]),'o', label='versicolor')
plt.plot(iris_virginica["petal length (cm)"], np.zeros_like(iris_virginica["petal length (cm)"]),'o', label='virginica')

plt.xlabel("Petal Length (cm)")
plt.ylabel("New Zero array of Petal Length size")
plt.legend()
plt.show()

# %% [markdown]
# ### ⚠️ Problems with 1D Scatter Plots
#
# * **Overlapping points** make it hard to know how many data points exist at each value. You can see 50 datapoints of setosa in between 1-2 cm of PL.
# * No visual count or density representation.
# * Last-drawn species might hide others behind them (some orange-vercicolor are hidden behind green-verginica).

# %% [markdown]
# ### 📊 Histograms: The Fix
#
# * Break X-axis (petal length) into **intervals or bins** (e.g., \[1.0–1.2], \[1.2–1.4], etc.)
# * Y-axis: **Count of data points** in each interval
# * Stack rectangles (bars) for each bin
# * Such a plot is called a **Histogram**.
# * In other words, Histogram is x-y plot where-
#     * x-axis is corresponding to the variable you are interested in, which is Petal Length here
#     * y-axis represents how often , how many times you find the data point corresponding to the given petal length.
# <br>
#
# #### 2 ways to create Histogram -
# 1. **sns.displot() (distribution plot)** - Simpler, Modern, Returns a FacetGrid
# 2. **sns.FacetGrid(...).map(...)** - An older-style, manual method to create faceted plots, then map a plotting function onto it.

# %%
# Seaborn Histogram (distribution plot)
# sns.displot(data=iris, x="petal length (cm)", hue="species", height=5);
sns.displot(
    data=iris,
    x="petal length (cm)",
    hue="species",
    bins=50,           # Increase number of intervals
    height=5
)
plt.show()

# %%
sns.FacetGrid(iris, hue="species", height=5).map(sns.histplot, "petal length (cm)", bins=50);
plt.show()

# %% [markdown]
# ### ✅ Benefits of Histograms
#
# * Clear count of how many data points exist in each interval.
# * Easier to compare species.
# * More readable than overlapping 1D scatter plot.

# %% [markdown]
# ### 📈 Probability Density Functions (PDFs)
#
# * Smooth versions of histograms
# * Use **Kernel Density Estimation (KDE)** to create them
# * Represent **how likely** a value is to appear
#
# ```python
# # KDE automatically added in seaborn displot
# sns.displot(data=iris, x="petal_length", hue="species", kind="kde", height=5)
# ```
#
# * The **blue line** is the PDF for Setosa
# * The **orange line** is the PDF for Versicolor
# * The **green line** is the PDF for Virginica
#
# ---
#
# ### 🧠 Intuition from Histogram + PDF
#
# * X-axis: Petal Length
# * Y-axis: Count or Density (i.e., how common a value is)
#
# #### Setosa Identification
#
# ```python
# if petal_length <= 2:
#     return "setosa"
# ```
#
# * No setosa flowers have petal length > 2.
# * Clear separation using this rule.
#
# #### Versicolor vs Virginica (Harder)
#
# * PDFs **overlap** significantly between 4.0 to 5.5
# * Can't find perfect rule, but can use probability intuition
#
# #### Rule Using Threshold (Intersection Point \~ 4.7)
#
# ```python
# if petal_length <= 2:
#     return "setosa"
# elif petal_length <= 4.7:
#     return "versicolor"
# else:
#     return "virginica"
# ```
#
# * At **4.7**, both PDFs intersect
# * Use **maximum PDF height** to decide which class has more presence
# * E.g.:
#
#   * At petal\_length = 5: PDF of Virginica > PDF of Versicolor → choose Virginica
#   * At petal\_length = 4.5: PDF of Versicolor > Virginica → choose Versicolor
#
# ---
#
# ### 📚 Concepts Recap
#
# * **1D Scatter Plot**: X-values only; Y=0; poor visibility due to overlap
# * **Histogram**: Buckets of feature range, shows count
# * **PDF**: Smoothed version of histogram, indicates density
#
# ---
#
# ### 🧪 Insights for Model Building
#
# * Histograms + PDFs can help build basic if-else rules
# * **Setosa** is cleanly separable with `petal_length <= 2`
# * **Versicolor vs Virginica** require threshold tuning
# * Rule can be set at **intersection of their PDFs** for best performance
#
# ---
#
# ### ⚠️ Limitation of 1D Plots
#
# * Work best when a **single feature** is informative
# * Fail when classes **overlap heavily** in 1D (e.g., Versicolor & Virginica)
# * Still useful for **preliminary analysis** and **intuition building**
#
# ---
#
# ### 📌 Coming Up Next
#
# * **Cumulative Density Function (CDF)**
# * How it complements histogram and PDF for better understanding

# %% [markdown]
# # 📊 Univariate Analysis using Histogram & PDF

# %% [markdown]
# ## 🧠 What is Univariate Analysis?
#
# **Univariate** analysis means analysis involving **only one variable**.
#
# It helps us understand:
# - The distribution of a single variable.
# - How this variable can distinguish between different classes (e.g., Setosa, Versicolor, Virginica in Iris dataset).
# ---

# %% [markdown]
# ## 🌸 Example: Iris Dataset
#
# We have 4 features:
# 1. Sepal Length
# 2. Sepal Width
# 3. Petal Length
# 4. Petal Width
#
# Goal: Identify **which single feature** best separates the three flower types:
# - Setosa
# - Versicolor
# - Virginica
# - ---

# %% [markdown]
# ## 📈 Using Histogram / PDF for Comparison
#
# Let’s plot histograms (or probability density functions) of each feature for all three classes and analyze the **overlap** between distributions.
#
# ---

# %% [markdown]
# ## 🔍 Petal Length
#
# - **Setosa** is **clearly separated** (none beyond length 2).
# - **Versicolor** and **Virginica** have **some overlap**.
# - ✅ **Good separation** between classes.
# 📌 **Conclusion**: Very useful for classification.

# %% [markdown]
# 📌 **Conclusion**: Very useful for classification.
#
# ---

# %%
sns.FacetGrid(iris, hue="species", size=5).map(sns.distplot, "petal_length").add_legend();
plt.show();
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 sns.FacetGrid(iris, hue="species", size=5).map(sns.distplot, "petal_length").add_legend();
#       2 plt.show();
#
# TypeError: FacetGrid.__init__() got an unexpected keyword argument 'size'

# %% [markdown]
# ## 🔍 Petal Width
#
# - **Setosa** is still well separated.
# - Small intersection between **Setosa** and others.
# - Some overlap between **Versicolor** and **Virginica**.
#
# 📌 **Conclusion**: Also useful, but **slightly less than petal length**.
#
# ---

# %%
sns.FacetGrid(iris, hue="species", size=5).map(sns.distplot, "petal_width").add_legend();
plt.show();
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 sns.FacetGrid(iris, hue="species", size=5) \
#       2    .map(sns.distplot, "petal_width") \
#       3    .add_legend();
#       4 plt.show();
#
# TypeError: FacetGrid.__init__() got an unexpected keyword argument 'size'

# %% [markdown]
# ## 🔍 Sepal Length
#
# - **Setosa**, **Versicolor**, and **Virginica** have significant **overlap**.
# - No clear separation of classes.
#
# 📌 **Conclusion**: **Not great** for classification.
#
# ---

# %%
sns.FacetGrid(iris, hue="species", size=5).map(sns.distplot, "sepal_length").add_legend();
plt.show();

# %% [markdown]
# ## 🔍 Sepal Width
#
# - Major **overlap** between **Versicolor** and **Virginica**.
# - Even **Setosa** not well separated.
#
# 📌 **Conclusion**: **Worst** among all four features.
#
# ---

# %%
sns.FacetGrid(iris, hue="species", size=5).map(sns.distplot, "sepal_width").add_legend();
plt.show();

# %% [markdown]
# # 🏁 Final Ranking of Features
#
# | Feature        | Usefulness (Separation)        |
# |----------------|-------------------------------|
# | Petal Length   | ⭐⭐⭐⭐ (Best)                    |
# | Petal Width    | ⭐⭐⭐                            |
# | Sepal Length   | ⭐⭐                             |
# | Sepal Width    | ⭐ (Worst)                      |
#
# ---

# %% [markdown]
# ## 💡 Rule of Thumb
#
# - The **less overlap** between class distributions → the **better** the feature.
# - Look for **well-separated** curves in the histogram/PDF.
#
# ---

# %% [markdown]
# ## ✅ Summary
#
# If we must:
# - Pick **one feature** → Choose **Petal Length**.
# - Pick **two features** → Choose **Petal Length** + **Petal Width**.
# - For more → Consider **pair plots** or **multivariate analysis**.
#
# ---

# %% [markdown]
# ## 📌 Note
#
# For advanced feature selection, consider:
# - Mutual information
# - Correlation with target
# - Feature importance from models

# %% [markdown]
# ## **🟣 Cumulative Distribution Function (CDF)**

# %% [markdown]
# #### **✅ What is CDF?**
# - The Cumulative Distribution Function (CDF) of a real-valued random variable X is the function:
#
#                             𝐹(𝑥)=𝑃(𝑋≤𝑥)
#
# - In simple terms, CDF gives the probability that a value from the dataset is less than or equal to x.

# %% [markdown]
# #### **🔵 Relation to PDF (Probability Density Function)**
# - PDF tells us how densely values are packed in a small range.
#
# - CDF tells us how many values lie below or equal to a given point.
#
# ![image.png](attachment:a62db82e-5746-4616-baeb-4ac9a6af9be0.png)

# %% [markdown]
# #### **🔸 Key Properties of CDF**
# - Always starts at 0 and ends at 1
#
# - Non-decreasing function
#
# - Horizontal axis = feature values
# Vertical axis = cumulative probability
#
# - Useful to find the threshold values and proportion of data below a point

# %% [markdown]
# #### **🧠 Why is CDF Useful?**
# - Helps us estimate:
#
#     - Proportion of data points below a threshold
#
#     - Classification boundaries in simple models
#
# - Gives more interpretable probabilities than PDFs
#
# - Great for threshold-based decisions (e.g. "If petal length ≤ 2.0 ➝ Setosa")

# %% [markdown]
# #### **🔧 How is CDF Computed?**
# (1) Sort the data.
#
# (2) For each point x, count how many values are ≤ x.
#
# (3) Divide the count by the total number of data points.
#
# (4) Plot x vs. this cumulative fraction.

# %% [markdown]
# ## **🟣 CDF and PDF with the Iris Dataset**

# %%
# Need for Cumulative Distribution Function (CDF)
# We can visually see what percentage of versicolor flowers have a 
# petal_length of less than 1.6?
# How to construct a CDF?
# How to read a CDF?

# Plot CDF of petal_length

counts, bin_edges = np.histogram(iris_setosa['petal_length'], bins=10, 
                                 density=True)

pdf = counts / (sum(counts))
print(pdf)
print(bin_edges)

# compute CDF
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:], pdf)
plt.plot(bin_edges[1:], cdf)

plt.show();
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'petal_length'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 9
# ...

# %%
# Plots of CDF of petal_length for various types of flowers.

# Misclassification error if you use petal_length only.
#setosa
counts, bin_edges = np.histogram(iris_setosa['petal_length'], bins=10, 
                                 density = True)

pdf = counts / (sum(counts))
print(pdf)
print(bin_edges)

cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:], pdf)
plt.plot(bin_edges[1:], cdf)

# virginica
counts, bin_edges = np.histogram(iris_virginica['petal_length'], bins=10, 
                                 density = True)

pdf = counts / (sum(counts))
print(pdf)
print(bin_edges)

cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:], pdf)
plt.plot(bin_edges[1:], cdf)

#versicolor
counts, bin_edges = np.histogram(iris_versicolor['petal_length'], bins=10, 
                                 density = True)

pdf = counts / (sum(counts))
print(pdf)
print(bin_edges)

cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:], pdf)
plt.plot(bin_edges[1:], cdf)

# %% [markdown]
# #### **📌 Real-World Use in Iris Classification**
# - For Setosa:
#
#     - All petal lengths ≤ 2.0 cm → clearly distinguishable via CDF
#
# - For Versicolor and Virginica:
#
#     - CDF helps determine accuracy at decision boundaries
#
#     - e.g., if petal length < 5.0 → Versicolor
#     → Check CDF at 5.0 for both classes to estimate accuracy

# %% [markdown]
# ## **🟣 Summary**

# %% [markdown]
# | Concept   | Explanation                                                                                                         |
# | --------- | ------------------------------------------------------------------------------------------------------------------- |
# | **PDF**   | Shows the probability distribution — how many data points lie in each range.                                        |
# | **CDF**   | Shows the cumulative probability up to a value — the proportion of data points less than or equal to a given value. |
# | **Usage** | Helps us understand thresholds and classification boundaries (e.g., petal length ≤ 2 → Setosa).                     |

# %% [markdown]
# ## **🟣 Understanding Mean, Variance, and Standard Deviation**

# %% [markdown]
# ### **📘 1. Introduction**
# In this notebook, we will explore:
#
# - The concept of mean (average)
#
# - Why mean can sometimes fail
#
# - How to handle spread using variance and standard deviation
#
# - Their mathematical intuition and Python implementation using NumPy
# ---

# %% [markdown]
# ### **🧠 2. What is Mean?**
# The mean is the central value of a dataset, often denoted by the Greek letter μ (mu).
#
# 📌 Formula:
#
# ![image.png](attachment:527770de-ebd6-4a7f-b583-a0c562656c00.png)
#
# ---

# %% [markdown]
# ### **🔢 Example: Mean of Setosa Petal Lengths**

# %%
#Mean, Variance, std-deviation
print("Means:")
print(np.mean(iris_setosa["petal_length"]))
#Mean with an outlier
print(np.mean(np.append(iris_setosa["petal_length"],50)));
print(np.mean(iris_virginica["petal_length"]))
print(np.mean(iris_versicolor["petal_length"]))

print("\nStd-dev:");
print(np.std(iris_setosa["petal_length"]))
print(np.std(iris_virginica["petal_length"]))
print(np.std(iris_versicolor["petal_length"]))
# Out:
# Means:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'petal_length'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 3
# ...

# %% [markdown]
# ### **⚠️ 3. Problem with Mean: Outliers**
# Even one wrong data point can skew the mean significantly.
#
# 📌 Example: Add a wrong value (e.g., 50) to Setosa petal lengths

# %%
# Append an outlier
setosa_with_outlier = np.append(setosa, 50)

# New mean after outlier
print("Original Mean:", np.mean(setosa))
print("Mean with Outlier:", np.mean(setosa_with_outlier))

# %% [markdown]
# ##### **🧠 Observation:**
# Even one erroneous value can drastically increase the mean, making it misleading.

# %% [markdown]
# ### **📘 4. Understanding Spread**
# While mean measures central tendency, it doesn't tell us how spread out the values are.
#
# We need to understand how much values deviate from the mean.

# %% [markdown]
# ### **📊 5. Variance**
# 📌 Formula:
#
# ![image.png](attachment:732ae8f6-0684-4ca6-aa6c-20e0bf1c2e8c.png)
#
# - Measures the average squared deviation from the mean.
#
# - Higher variance → data is more spread out.

# %%
print("Setosa Variance:", np.var(setosa))
print("Versicolor Variance:", np.var(versicolor))
print("Virginica Variance:", np.var(virginica))

# %% [markdown]
# ### **📏 6. Standard Deviation**
# Standard Deviation is the square root of the variance:
# ![image.png](attachment:c2b9398b-0987-4486-80c2-c467ce03a55c.png)
#
# It tells us how far the values are spread in the same units as the original data.

# %% [markdown]
# ### **🔍 7. Interpreting Spread**
# You can estimate where most data points lie by:
# [μ−σ,μ+σ]

# %% [markdown]
# ### **✅ 10. Summary**

# %% [markdown]
# | Concept           | Description                                        | Sensitive to Outliers |
# | ----------------- | -------------------------------------------------- | --------------------- |
# | **Mean (μ)**      | Average of all values                              | ✅ Yes                 |
# | **Variance (σ²)** | Average squared deviation from mean                | ✅ Yes                 |
# | **Std Dev (σ)**   | Square root of variance (spread in original units) | ✅ Yes                 |

# %% [markdown]
# ## **🟣 Understanding Median: A Robust Measure of Central Tendency**

# %% [markdown]
# **📌 Why Median?**
#
# We’ve seen that:
#
# Mean, Variance, and Standard Deviation are sensitive to outliers.
#
# Even a single extreme value can drastically change the mean.
#
# So, the question is:
#
# Is there a measure of central tendency that is resistant to outliers?
#
# **✅ Yes! That’s the Median.**
#
# ---

# %% [markdown]
# ## **📘 Definition of Median**
# The Median is the middle value in a sorted list of numbers.
#
# - If n is odd, the median is the middle value.
#
# - If n is even, the median is the average of the two middle values.

# %% [markdown]
# ## **🔢 Code Demonstration with NumPy**

# %%
import numpy as np

# Example: Petal lengths of Setosa (without outlier)
setosa_petal_lengths = [1.4, 1.5, 1.3, 1.5, 1.4, 1.3, 1.5]
median_without_outlier = np.median(setosa_petal_lengths)

# Adding an extreme outlier (50)
setosa_with_outlier = setosa_petal_lengths + [50]
median_with_outlier = np.median(setosa_with_outlier)

print("Median without outlier:", median_without_outlier)
print("Median with outlier   :", median_with_outlier)
# Out:
# Median without outlier: 1.4
# Median with outlier   : 1.45

# %% [markdown]
# **✔️ Output: The median remains the same even after adding an outlier!**

# %% [markdown]
# ## **📊 Comparison with Mean**

# %%
mean_without_outlier = np.mean(setosa_petal_lengths)
mean_with_outlier = np.mean(setosa_with_outlier)

print("Mean without outlier:", mean_without_outlier)
print("Mean with outlier   :", mean_with_outlier)
# Out:
# Mean without outlier: 1.4142857142857144
# Mean with outlier   : 7.487500000000001

# %% [markdown]
# **❌ Mean is heavily affected by the outlier.**

# %% [markdown]
# ## **🧮 How to Calculate Median (Step-by-Step)**

# %% [markdown]
# ### **▶️ Case 1: Odd Number of Elements**

# %%
# Given data (unsorted)
x = [1, 1.2, 1.1, 2.1, 1.8, 1.6, 1.2]

# Step 1: Sort the data
x_sorted = sorted(x)

# Step 2: Find the middle value
n = len(x_sorted)
median = x_sorted[(n // 2)]  # 0-based indexing

print("Sorted data:", x_sorted)
print("Median (odd n):", median)
# Out:
# Sorted data: [1, 1.1, 1.2, 1.2, 1.6, 1.8, 2.1]
# Median (odd n): 1.2

# %% [markdown]
# ### **▶️ Case 2: Even Number of Elements**

# %%
# Adding one more value to make it even
x_even = x + [1.8]
x_even_sorted = sorted(x_even)
n_even = len(x_even_sorted)

# Median = average of n/2 and (n/2 - 1) indices
median_even = (x_even_sorted[n_even // 2 - 1] + x_even_sorted[n_even // 2]) / 2

print("Sorted data (even):", x_even_sorted)
print("Median (even n):", median_even)
# Out:
# Sorted data (even): [1, 1.1, 1.2, 1.2, 1.6, 1.8, 1.8, 2.1]
# Median (even n): 1.4

# %% [markdown]
# ## **⚠️ Why is Median Robust to Outliers?**

# %%
# Original data
x_clean = [1, 1.1, 1.2, 1.4, 1.6, 1.8, 2.0]
median_clean = np.median(x_clean)

# Add one outlier
x_with_outlier = x_clean + [56]
median_with_outlier = np.median(x_with_outlier)

print("Median without outlier:", median_clean)
print("Median with one outlier:", median_with_outlier)
# Out:
# Median without outlier: 1.4
# Median with one outlier: 1.5

# %% [markdown]
# **✅ Result: Median barely changes**
#
# **❌ Mean would be highly affected**

# %% [markdown]
# ### **⚠️ When Median Fails? (Majority Corrupted)**

# %%
# Majority corrupted data
x_bad = [1, 1.1, 1.2, 10, 20, 30, 40]
median_bad = np.median(x_bad)

print("Corrupted data:", x_bad)
print("Median (with majority corrupted):", median_bad)
# Out:
# Corrupted data: [1, 1.1, 1.2, 10, 20, 30, 40]
# Median (with majority corrupted): 10.0

# %% [markdown]
# ### **✅ Summary: Median vs Mean**

# %% [markdown]
# | Feature              | Mean  | Median          |
# | -------------------- | ----- | --------------- |
# | Affected by Outliers | ✅ Yes | ❌ No (if < 50%) |
# | Easy to Compute      | ✅ Yes | ✅ Yes           |
# | Represents Center    | ✅ Yes | ✅ Yes           |
# | Robustness           | ❌ Low | ✅ High          |

# %% [markdown]
# ### **📌 Conclusion**

# %% [markdown]
# - Median is a robust alternative to the mean.
#
# - It’s simple to calculate: just sort the data and pick the middle value.
#
# - Ideal for datasets with outliers or skewed distributions.

# %% [markdown]
# ## **📊 Understanding Percentiles and Quantiles**
# In this notebook, we will understand the concepts of percentiles and quantiles, which are useful alternatives to mean and standard deviation—especially when dealing with outliers.

# %% [markdown]
# ### **🧠 What is a Percentile?**
# A percentile indicates the value below which a given percentage of observations fall in a sorted dataset.
#
# ### **🔢 Example:**
# - Let’s say we have 100 sorted values.
#
# - The 50th percentile is the value at the 50th index in this sorted list.
#
# - This value means that 50% of the values are less than or equal to it.

# %%
import numpy as np

# Sample sorted data
x = np.arange(1, 101)  # 100 values from 1 to 100

# Calculate 50th percentile
np.percentile(x, 50)
# Out:
# np.float64(50.5)

# %% [markdown]
# ### **🟢 Understanding Median via Percentile**
# - Median is the 50th percentile.
#
# - It splits the data into two equal halves.

# %%
# Median = 50th percentile
median = np.percentile(x, 50)
print("Median:", median)
# Out:
# Median: 50.5

# %% [markdown]
# ### **🔷 What is a Quantile?**
# A quantile is just a special kind of percentile:

# %% [markdown]
# | Quantile | Percentile | Description              |
# | -------- | ---------- | ------------------------ |
# | Q1       | 25%        | First Quartile           |
# | Q2       | 50%        | Second Quartile = Median |
# | Q3       | 75%        | Third Quartile           |
# | Q4       | 100%       | Maximum Value            |

# %%
# Get 0th, 25th, 50th, 75th percentiles
quantiles = np.percentile(x, [0, 25, 50, 75])
print("Quantiles:", quantiles)
# Out:
# Quantiles: [ 1.   25.75 50.5  75.25]

# %% [markdown]
# ### **📈 Percentiles in Real Data Example (Iris Dataset)**

# %%
from sklearn.datasets import load_iris
import pandas as pd

# Load iris dataset
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['species'] = iris.target

# Group by species and calculate percentiles for a feature
df.groupby('species')['sepal length (cm)'].quantile([0.25, 0.5, 0.75])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from sklearn.datasets import load_iris
#       2 import pandas as pd
#       4 # Load iris dataset
#
# ModuleNotFoundError: No module named 'sklearn'

# %% [markdown]
# ### **⚙️ Custom Percentiles**

# %%
# Get custom percentiles: 10th, 90th
p10 = np.percentile(x, 10)
p90 = np.percentile(x, 90)

print("10th Percentile:", p10)
print("90th Percentile:", p90)
# Out:
# 10th Percentile: 10.9
# 90th Percentile: 90.10000000000001

# %% [markdown]
# ### **🏬 Real-Life Use Case: Delivery Times**

# %% [markdown]
# #### **Scenario:**
# Suppose you work at Amazon and analyze delivery times:

# %%
# Simulated delivery times (in days)
delivery_times = np.random.normal(loc=3, scale=1, size=10000)

# Clip to ensure positive values
delivery_times = np.clip(delivery_times, 1, None)

# 95th and 99th percentiles
p95 = np.percentile(delivery_times, 95)
p99 = np.percentile(delivery_times, 99)

print("95th Percentile Delivery Time:", p95)
print("99th Percentile Delivery Time:", p99)
# Out:
# 95th Percentile Delivery Time: 4.640879677607433
# 99th Percentile Delivery Time: 5.29778634199568

# %% [markdown]
# ### **✅ Interpretation:**
# - 95th Percentile = 4.2 days → 95% of orders were delivered in under 4.2 days.
#
# - 99th Percentile = 5.5 days → 99% of orders were delivered in under 5.5 days.
#
# - These metrics help identify delivery delays and improve customer satisfaction.

# %% [markdown]
# ### **✅ Summary**

# %% [markdown]
# | Term       | Meaning                                                                 |
# | ---------- | ----------------------------------------------------------------------- |
# | Percentile | A value below which a percentage of observations fall                   |
# | Median     | 50th Percentile                                                         |
# | Quantile   | General term dividing data into equal-sized intervals (e.g., quartiles) |
# | Use Case   | Understand delivery performance, cutoff thresholds, etc.                |

# %% [markdown]
# ## **🟣Robust Statistics: Median, MAD, and IQR**

# %% [markdown]
# ### **📌 1. Mean vs Median**
# - Mean: Average value. Affected by outliers.
#
# - Median: Middle value in sorted data. Not affected by outliers.

# %%
import numpy as np

data = [1, 2, 3, 4, 100]  # 100 is an outlier
print("Mean:", np.mean(data))      # Heavily affected by 100
print("Median:", np.median(data))  # Stable and robust
# Out:
# Mean: 22.0
# Median: 3.0

# %% [markdown]
# ### **📌 2. Standard Deviation (σ)**

# %% [markdown]
# Standard deviation measures the average distance of each point from the mean.
# ##### **Formula:**
#
# ![image.png](attachment:6e9b94f2-20a4-4761-b971-c98f97b129b3.png)

# %%
std_dev = np.std(data)
print("Standard Deviation:", std_dev)
# Out:
# Standard Deviation: 39.01281840626232

# %% [markdown]
# ### **📌 3. Median Absolute Deviation (MAD)**

# %% [markdown]
# MAD measures the typical distance of data points from the median, not the mean.
# It’s robust and not affected by extreme values (outliers).
#
# **Steps to calculate MAD:**
#
# 1. Find the median of the data.
#
# 2. Compute absolute deviation from median: |xi - median|
#
# 3. Find the median of all absolute deviations.
#
# **Formula:**
# MAD=median(∣xi−median(x)∣)

# %% [markdown]
# **✅ Python Implementation (using statsmodels):**

# %%
from statsmodels import robust

print("Median Absolute Deviation:", robust.mad(data))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from statsmodels import robust
#       3 print("Median Absolute Deviation:", robust.mad(data))
#
# ModuleNotFoundError: No module named 'statsmodels'

# %% [markdown]
# ### **📌 4. Percentiles and Quantiles**
# - Percentile: The value below which a given % of data falls.
#
#     - e.g., 75th percentile = 75% of data lies below this value.
#
# - Quantile: Equivalent concept. 25th percentile = 0.25 quantile.

# %%
q1 = np.percentile(data, 25)  # 1st quartile (25th percentile)
q3 = np.percentile(data, 75)  # 3rd quartile (75th percentile)
print("Q1 (25th percentile):", q1)
print("Q3 (75th percentile):", q3)
# Out:
# Q1 (25th percentile): 2.0
# Q3 (75th percentile): 4.0

# %% [markdown]
# ### **📌 5. Interquartile Range (IQR)**
# The IQR is the middle 50% of your data.
# It's a measure of spread using percentiles.
#
# **Formula:**
#
# 𝐼𝑄𝑅=𝑄3−𝑄1

# %%
iqr = q3 - q1
print("Interquartile Range:", iqr)
# Out:
# Interquartile Range: 2.0

# %% [markdown]
# - 25% of values < Q1
#
# - 25% of values > Q3
#
# - So, 50% of data lies between Q1 and Q3

# %% [markdown]
# ### **📌 6. Why Use MAD and IQR?**
# - Both are robust statistics: not influenced by extreme values.
#
# - Useful in outlier detection, especially when data is not normally distributed.
#
# - MAD is a better robust alternative to Standard Deviation.
#
# - IQR is useful in boxplots and spread analysis.

# %% [markdown]
# ### **📊 Optional: Visualize These Concepts (Boxplot)**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(data)
plt.title("Boxplot Showing Median, IQR, and Outliers")
plt.show()

# %% [markdown]
# ### **✅ Recap**

# %% [markdown]
# | Concept | Central Value | Spread/Deviation | Robust to Outliers? |
# | ------- | ------------- | ---------------- | ------------------- |
# | Mean    | Mean          | Std Dev (σ)      | ❌ No                |
# | Median  | Median        | MAD              | ✅ Yes               |
# | Median  | Median        | IQR              | ✅ Yes               |

# %% [markdown]
# # 📦 Understanding Box Plots and Whiskers in Data Visualization

# %% [markdown]
# ## 📊 Background: Why Box Plots?
# We previously explored **histograms** and **PDFs** to understand distributions.
#
# ### ❗ Problem with Histograms:
# - Histograms show how dense the data is at different values.
# - But they **do not** help us identify **percentile values** (like 25th, 50th, 75th) easily.
#
# ### ✅ CDFs (Cumulative Distribution Functions) Help:
# - From CDFs, we can identify percentile values by drawing horizontal and vertical lines.
# - Example: If the CDF crosses 0.25 at petal length = 1.3, then **25th percentile = 1.3**.
#
# ### ❓ Can we get percentile values more easily?
# Yes! ➤ **Box plots** are designed to represent percentiles directly and clearly.
#
# ---
#
# ## 📦 What is a Box Plot?
#
# A **box plot** (also known as a **box-and-whisker plot**) uses percentiles to summarize the distribution of a dataset.
#
# ### 🔹 Box Plot in Seaborn:

# %% [markdown]
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# sns.boxplot(x='species', y='petal_length', data=iris)
# plt.show()

# %% [markdown]
# - x-axis: Species (setosa, versicolor, virginica)
#
# - y-axis: Petal length

# %% [markdown]
# ### **🔍 Reading the Box Plot**
# For each class (species), you get a box and whiskers.
#
# ### **📏 The Box:**
# - Bottom edge: 25th percentile (Q1)
#
# - Middle line: 50th percentile (Median)
#
# - Top edge: 75th percentile (Q3)
#
# ➡️ The box represents the Interquartile Range (IQR) = Q3 - Q1
# ➡️ The width of the box has no meaning (just aesthetics in Seaborn).

# %% [markdown]
# ### **🐈 What Are Whiskers?**

# %% [markdown]
# #### **🔸 Whiskers:**
# - Represent the "spread" beyond the box.
#
# - Different ways to define whiskers:
#
#     1. Min and Max values
#
#     2. Seaborn's method:
#     Whiskers extend to points within 1.5 × IQR from Q1 and Q3.
#
#     3. Any custom method
#
# ⚠️ There's no universal standard for whisker length.
# But they typically contain most of the data points.

# %% [markdown]
# ### **⚙️ Use Case: Classification Rule from Box Plot**
# Imagine a classification rule like:

# %%
if 2 < petal_length < 5:
    predict = "versicolor"
elif petal_length >= 5:
    predict = "virginica"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 if 2 < petal_length < 5:
#       2     predict = "versicolor"
#       3 elif petal_length >= 5:
#
# NameError: name 'petal_length' is not defined

# %% [markdown]
# - From the box plot:
#
#     - The 25th percentile of virginica is around 5.
#
#     - So, 25% of virginica samples will be misclassified as versicolor.
#
# ✅ With this simple threshold logic, you can visually estimate classification errors!

# %% [markdown]
# ### **📌 Summary: Why Box Plots Are Useful**
# - Easy to read 25th, 50th, 75th percentiles
#
# - Quickly see where majority of data lies
#
# - Helps in decision making (e.g., choosing thresholds)
#
# - Complementary to histograms, PDFs, and CDFs
#
# - Box plots visualize:
#
#     - Median (50th percentile)
#
#     - Quartiles (25th and 75th percentile)
#
#     - Spread of most of the data
#
#     - Potential outliers (shown as dots beyond whiskers)

# %% [markdown]
# ### **✅ Key Concepts Recap**
# | Term        | Meaning                         |
# | ----------- | ------------------------------- |
# | Q1          | 25th percentile                 |
# | Q2 / Median | 50th percentile                 |
# | Q3          | 75th percentile                 |
# | IQR         | Q3 - Q1 (Interquartile Range)   |
# | Whiskers    | Range covering most data points |
# | Outliers    | Points beyond whiskers          |

# %% [markdown]
# # 📊 Violin Plot: Merging Box Plot and PDF
#
# In data visualization, we’ve already explored:
# - **Histograms** and **Probability Density Functions (PDFs)**
# - **Box Plots**
#
# Each has its own strengths:
# - 📦 **Box Plot** helps visualize percentiles and outliers.
# - 📈 **PDF/Histogram** shows the distribution shape.
#
# But what if we want the **best of both worlds**?
# 👉 Enter the **Violin Plot**.
#
# ---
#
# ## 🎻 What is a Violin Plot?
#
# A **violin plot** combines the information of:
# - **Box plots** (percentiles, whiskers, median)
# - **Density plots** (smooth histogram/PDF)
#
# The name comes from its **violin-like shape** 🎻.
#
# ---
#
# ## 🔍 Components of a Violin Plot
#
# Here's what you see in a violin plot:
#
# ### 1. **Box Plot (Inside the Violin)**
# - The **thick black box** in the center is the traditional box plot.
# - Contains:
#   - **White dot**: Median (50th percentile)
#   - **Top edge of box**: 75th percentile (Q3)
#   - **Bottom edge of box**: 25th percentile (Q1)
#   - **Whiskers**: Data range (typically Q1 - 1.5*IQR to Q3 + 1.5*IQR)
#
# ### 2. **Density Plot (Outer Shape)**
# - The **violin shape** on either side of the box is the **PDF** (Probability Density Function).
# - Symmetric and smooth — like a **bell curve** (if Gaussian).
#
# This gives us insight into both:
# - **Data distribution** (shape and spread)
# - **Statistical summary** (via box plot)
#
# ---
#
# ## 📈 Visual Example (Using Seaborn)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Sample dataset
# df = sns.load_dataset('iris')
#
# # Violin plot
# sns.violinplot(x='species', y='petal_length', data=df)
# plt.title("Violin Plot of Petal Length Across Iris Species")
# plt.show()

# %% [markdown]
# ### **🧠 Why Use Violin Plots?**
# ✅ Combines distribution and summary statistics
#
# ✅ Helps detect:
#
# - Skewness
#
# - Multi-modal distributions
#
# - Outliers
#
# ✅ More informative than just box or histogram alone

# %% [markdown]
# ### **💡 Summary**

# %% [markdown]
# | Feature      | Box Plot | PDF | Violin Plot |
# | ------------ | -------- | --- | ----------- |
# | Median       | ✅        | ❌   | ✅           |
# | Quartiles    | ✅        | ❌   | ✅           |
# | Distribution | ❌        | ✅   | ✅           |
# | Outliers     | ✅        | ❌   | ✅           |

# %% [markdown]
# ### **📝 To Be Covered Later**
# The violin shape is often Gaussian (bell curve).
# If you're unfamiliar with this, don’t worry — we'll cover Gaussian distributions in detail during probability lessons.

# %% [markdown]
# ### **✅ Conclusion**
# Violin plots are a simple yet powerful way to visualize data.
# They combine statistical summaries with distribution shapes, giving us clear and complete insight into the data.
#
# **💬 "It gives us the best of both worlds."**

# %% [markdown]
# ## **📘 Summarizing Plots, Univariate, Bivariate and Multivariate analysis**

# %% [markdown]
# ### **🔹 1. Importance of Writing Conclusions in Simple English**
# As a data scientist, data analyst, or ML engineer, it’s crucial not only to perform analysis but also to communicate results effectively.
#
# - Always summarize your plots in plain English.
#
# - Use terms like "Observations" or "Conclusions" under plots.
#
# - Avoid technical jargon; your audience may include non-technical stakeholders from marketing, sales, etc.
#
# - Example:
#
#     "From the pair plot, petal length and petal width are important features in distinguishing Setosa from other species. However, Versicolor and Virginica are harder to separate."
#
# ✅ If others can’t understand your analysis, it can’t lead to action—even if the work is technically correct.

# %% [markdown]
# ### **🔹 2. Stay Aligned with Your Objective**
# Always remember:
#
# 🎯 Your analysis must be driven by the objective you're trying to solve.
#
# - Our objective here: Classify flowers into Setosa, Versicolor, and Virginica.
#
# - Avoid irrelevant findings or insights that don’t help the main goal.
#
# ❌ Example of losing focus:
#
#     Analyzing only Setosa flowers to demonstrate histogram concepts has no direct contribution to solving the classification problem.
#
# ✅ Do this only in educational settings — not in real-world problem solving.

# %% [markdown]
# ## **🔹 3. Types of Data Analysis**
#
# ### **📊 Univariate Analysis
# - Analyzing one variable at a time
#
# - Examples:
#
#     - Histograms
#
#     - Box plots
#
#     - Violin plots
#
#     - PDFs, CDFs
#
# Useful for understanding distribution, central tendency, spread, and outliers.

# %% [markdown]
# ### **📉 Bivariate Analysis**
# - Analyzing two variables together
#
# - Examples:
#
#     - Scatter plots
#
#     - Pair plots (2D combinations)
#
# Helps identify relationships or correlations between two features (e.g., petal length vs petal width).

# %% [markdown]
# ### **📈 Multivariate Analysis**
# - Analyzing three or more variables
#
# - Example:
#
#     - 3D scatter plots
#
#     - Any ML model using multiple features
#
# All of machine learning can be viewed as an advanced form of multivariate analysis.

# %% [markdown]
# ### **🧠 Final Thoughts**
# - Always conclude your visualizations with clear takeaways.
#
# - Keep your analysis objective-driven.
#
# - Understand and apply the type of analysis appropriate for the number of variables.
#
# - Remember: Clarity > Complexity
